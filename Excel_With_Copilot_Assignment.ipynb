# %% [markdown]
# 1. Use Copilot to identify and summarize missing values in the dataset
#
#     Answer:
#
#     Missing values found in:
#
# - Region column: Missing in ORD0010, ORD0018, ORD0031, ORD0064, ORD0118, ORD0122.
#
# - Category column: Missing in ORD0025, ORD0159.
#
# - Units Sold column: Missing in ORD0131.
#
# - Unit Price column: Missing in ORD0028, ORD0080, ORD0092, ORD0146.
#
# - Other scattered gaps: A few rows have incomplete merged cells in later tables.

# %% [markdown]
# 2. Use Copilot to fill missing values in the Region and Category columns.
#
# Answer:
#
# Region: Can be inferred from country patterns. Example:
#
# - ORD0010 (USA, Furniture) → Region = East (consistent with other USA Furniture entries).
#
# - ORD0018 (India, Clothing) → Region = East (India entries mostly East/West).
#
# - ORD0031 (India, Beverages) → Region = East.
#
# - ORD0064 (USA, Beverages) → Region = East.
#
# - ORD0118 (Germany, Clothing) → Region = North.
#
# - ORD0122 (Australia, Electronic) → Region = South.
#
# Category:
#
# - ORD0025 (India, Offline) → Likely Food (most India Offline entries are Food).
#
# - ORD0159 (UK, Offline) → Likely Furniture (UK Offline entries mostly Furniture).

# %% [markdown]
# 3. Fill missing numeric values in the Unit Sold and Unit Price columns.
#
# Answer:
# - Units Sold: ORD0131 missing → can be imputed using average Furniture Offline sales (~300–400 units).
#
# - Unit Price:
#
# ORD0028 → fill with average Food Online price (~250).
#
# ORD0080 → Clothing Online average (~200).
#
# ORD0092 → Electronic Offline average (~250).
#
# ORD0146 → Furniture Online average (~300).

# %% [markdown]
# 4. Create a new calculated column Total Revenue.
#
# Answer:
#
# Formula:
# ```
# Total Revenue= Units Sold × Unit Price
# ```
# Example:
#
# - ORD0001:  235×152.92= 35,958.2
#
# - ORD0123: 46×344.55= 15,865.3

# %% [markdown]
# 5. Use Copilot to find the total price of Order ID = ‘ORD0123’.
#
# Answer:
#
# - Units Sold = 46
# - Unit Price = 344.55
# - Total Revenue = 15,865.3

# %% [markdown]
# 6. Use Copilot to generate a summary chart of average profit by region.
#
# Answer:
#
# Profit formula:
# ```
#
# Profit= (Unit Price − Unit Cost) × Units Sold
# ```
#
# Example averages (approx):
#
# - East: Moderate profit, Furniture & Food dominate.
# - West: Higher profits in Electronics.
# - North: Mixed, Clothing lower margins.
# - South: Electronics & Beverages strong.
#
# (Visual chart would show South & West leading in average profit.)

# %% [markdown]
# 7. Create a pivot table summarizing total sales by category and region.
#
# Answer:
# ![Screenshot pivot table of copilot excel aasign.png](data:image/png;base64,...)

# %% [markdown]
# 8. Build a dashboard combining key KPIs and charts.
#
# Answer:
#
# Key KPIs:
#
# - Total Revenue (sum across all orders).
# - Average Profit by Region (bar chart).
# - Category-wise Sales Distribution (pie chart).
# - Top 5 Orders by Revenue (table).
# - Monthly Trend of Sales (line chart).

# %% [markdown]
# 9. Use Copilot to generate a summary report.
#
# Answer:
# - Data Quality: Missing values in Region, Category, Units Sold, Unit Price.
# - Revenue Drivers: Electronics and Furniture orders dominate revenue.
# - Regional Insights: West and South regions show higher profitability.
# - Category Insights: Beverages and Food have high sales volume but lower margins; Electronics yield higher profits.
# - Recommendations: Focus on Electronics in West/South, improve data completeness, monitor Furniture sales in East.
